# %% [markdown]
# # Data Wrangling with Python and Pandas

# %% [markdown]
# ### Titanic Data set

# %% [markdown]
# ###### import needed module

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/pradeeppaladugula/Documents/GitHub/anly560-fall2020/python-programming/week-07/data/train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Filtering the data

# %%
#filtering the data pasengers older than 30
df[df['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Filter data : female and over 30

df[(df['Age'] > 30) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#save filter toa variabler

femaleOver30 = df[(df['Age'] > 30) & (df['Sex']=='female')]
female30AndUnder = df[(df['Age'] <= 30) & (df['Sex']=='female')]
maleOver30 = df[(df['Age'] > 30) & (df['Sex']=='male')]
male30AndUnder = df[(df['Age'] <= 30) & (df['Sex']=='male')]

# %%
femaleOver30.describe()
female30AndUnder.describe()
maleOver30.describe()
male30AndUnder.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   251.000000  251.000000  251.000000  251.000000  251.000000
# mean    437.633466    0.207171    2.585657   20.482749    0.577689
# std     264.285212    0.406089    0.672037    7.780181    1.140588
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     206.500000    0.000000    2.000000   18.000000    0.000000
# 50%     404.000000    0.000000    3.000000   22.000000    0.000000
# 75%     686.500000    0.000000    3.000000   26.000000    1.000000
# max     890.000000    1.000000    3.000000   30.000000    5.000000
#
#             Parch        Fare
# count  251.000000  251.000000
# mean     0.314741   22.923969
# std      0.639173   33.308266
# min      0.000000    0.000000
# 25%      0.000000    7.881250
# 50%      0.000000   10.170800
# 75%      0.000000   26.000000
# max      3.000000  263.000000

# %% [markdown]
# ##### Grouping Data

# %%
df.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# ##### Exporting data

# %%
#export femaleover30 dataset to excel
femaleOver30.to_excel('/Users/pradeeppaladugula/Documents/GitHub/anly560-fall2020/python-programming/week-07/data/femalesOverThirty.xlsx')

# %% [markdown]
# ##### Time Series Data

# %% [markdown]
# ###### Examples of Time Series Data

# %%
#Customer Demand
#flight trafic
#Weather Forcasting
# Prod live environment
#Blood pressure and weight
#Sales Forcasting

# %%
#import needed modules
from datetime import datetime
import matplotlib
import matplotlib.pyplot as pyplot
import numpy as np

# %%
#create an array of 200 elements at 1sec intervals 
#this is indices of different time perisod (for example if we want a box at 150s, 150s is a indices)
time_series_index = pd.date_range('1/1/2020', periods=200, freq='s')
print(time_series_index)
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:01',
#                '2020-01-01 00:00:02', '2020-01-01 00:00:03',
#                '2020-01-01 00:00:04', '2020-01-01 00:00:05',
#                '2020-01-01 00:00:06', '2020-01-01 00:00:07',
#                '2020-01-01 00:00:08', '2020-01-01 00:00:09',
#                ...
#                '2020-01-01 00:03:10', '2020-01-01 00:03:11',
#                '2020-01-01 00:03:12', '2020-01-01 00:03:13',
#                '2020-01-01 00:03:14', '2020-01-01 00:03:15',
#                '2020-01-01 00:03:16', '2020-01-01 00:03:17',
#                '2020-01-01 00:03:18', '2020-01-01 00:03:19'],
#               dtype='datetime64[ns]', length=200, freq='S')

# %%
#Create time series data by assign Random Integer Values
time_series = pd.Series(np.random.randint(0,500, len(time_series_index)), index=time_series_index)

#print out the first few values to understand how the data looks like 
#(using head() functions gives overview of the data).
print(time_series.head())
# Out:
# 2020-01-01 00:00:00    291
# 2020-01-01 00:00:01    145
# 2020-01-01 00:00:02    305
# 2020-01-01 00:00:03    384
# 2020-01-01 00:00:04    297
# Freq: S, dtype: int64

# %%
#resample 1 second bin to minute and sim the corresponding values
time_series_min = time_series.resample('1Min').sum()

#print out the first few values to understand how the data looks like 
print(time_series_min.head())
# Out:
# 2020-01-01 00:00:00    14239
# 2020-01-01 00:01:00    15296
# 2020-01-01 00:02:00    16151
# 2020-01-01 00:03:00     4876
# Freq: T, dtype: int64

# %%
#time zone conversion - assume original time series was in UTC and we want US EST

time_series_utc = time_series.tz_localize('UTC')
print(time_series_utc.head())
# Out:
# 2020-01-01 00:00:00+00:00    291
# 2020-01-01 00:00:01+00:00    145
# 2020-01-01 00:00:02+00:00    305
# 2020-01-01 00:00:03+00:00    384
# 2020-01-01 00:00:04+00:00    297
# Freq: S, dtype: int64

# %%
#The Time Values of above are all Zeros as per the Universal Time Code (Greenwich mean time). So when we the above output
#to the "US/Eastern" timezone then it shows, the time is +5hours from the Greenwich mena time.
#Greenwich is in England, thats where the time started and its really a myth.

# %%
#convert to US EST
time_series_est = time_series_utc.tz_convert('US/Eastern')
print(time_series_est.head())
# Out:
# 2019-12-31 19:00:00-05:00    291
# 2019-12-31 19:00:01-05:00    145
# 2019-12-31 19:00:02-05:00    305
# 2019-12-31 19:00:03-05:00    384
# 2019-12-31 19:00:04-05:00    297
# Freq: S, dtype: int64
